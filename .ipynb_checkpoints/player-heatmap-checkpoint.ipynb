# %%
#import the needed lib

import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
from mplsoccer.pitch import VerticalPitch
import seaborn as sns

# %%
#call the data using pandas

df = pd.read_csv('./data/player-analyst/qatar-ekuador.csv')
df.head()
# Out:
#       Team          Player    Event  Mins  Secs   X   Y  X2  Y2
# 0  Ekuador      M Calceido     Pass     0    34  55  55  32  56
# 1    Qatar      Akram Afif  Dribble     1    25  46   3  50  23
# 2  Ekuador      M Calceido  Dribble     1    53  46  52  35  59
# 3  Ekuador  Enner Valencia     Shot     2    55   5  53   1  52
# 4  Ekuador      M Calceido  Dribble     4    12  63  78  59  83

# %%
df.describe()
# Out:
#              Mins        Secs           X           Y          X2          Y2
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    36.818966   28.344828   55.096552   39.717241   55.613793   38.324138
# std     24.193279   15.886064   23.905153   18.509092   26.816526   19.188106
# min      0.000000    2.000000    2.400000    2.400000    1.200000    1.600000
# 25%     15.750000   14.000000   36.900000   23.000000   38.100000   21.600000
# 50%     30.000000   25.000000   55.800000   41.600000   54.000000   39.600000
# 75%     54.000000   40.250000   73.500000   54.600000   72.300000   50.600000
# max     88.000000   59.000000  108.000000   76.800000  118.800000   73.600000

# %%
df['X'] = df['X']*1.2
df['Y'] = df['Y']*0.8
df['X2'] = df['X2']*1.2
df['Y2'] = df['Y2']*0.8

# %%
df.head()
# Out:
#       Team          Player    Event  Mins  Secs     X     Y    X2    Y2
# 0  Ekuador      M Calceido     Pass     0    34  66.0  44.0  38.4  44.8
# 1    Qatar      Akram Afif  Dribble     1    25  55.2   2.4  60.0  18.4
# 2  Ekuador      M Calceido  Dribble     1    53  55.2  41.6  42.0  47.2
# 3  Ekuador  Enner Valencia     Shot     2    55   6.0  42.4   1.2  41.6
# 4  Ekuador      M Calceido  Dribble     4    12  75.6  62.4  70.8  66.4

# %% [markdown]
# ## Full Time Movement

# %%
#draw the pitch
fig,ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

pitch = Pitch(pitch_type='statsbomb', half=False, pitch_length=120, pitch_width=80,
             pitch_color='#22312b', line_color='#c7d5cc')
pitch.draw(ax=ax)
# plt.gca().invert_yaxis()

#draw the player movements
for x in range(len(df['X'])):
    if df['Player'][x] == "Enner Valencia":
        if df['Mins'][x] <= 45:
            plt.plot([int(df["X"][x]), int(df["X2"][x])], [int(df["Y"][x]), int(df["Y2"][x])], color='green')
        
        #because the football teams will be change their side in the second half, so we need to flip the X and Y
        elif df['Mins'][x] > 45:
            plt.plot([int(120-df["X"][x]), int(120-df["X2"][x])], [int(80-df["Y"][x]), int(80-df["Y2"][x])], color='blue')

# %% [markdown]
# # First Half Movement

# %%
#draw the pitch
fig,ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

pitch = Pitch(pitch_type='statsbomb', half=False, pitch_length=120, pitch_width=80,
             pitch_color='#22312b', line_color='#c7d5cc')
pitch.draw(ax=ax)
# plt.gca().invert_yaxis()

#draw the player movements
for x in range(len(df['X'])):
    if (df['Player'][x] == "Akram Afif") and (df['Mins'][x] <=45):
        plt.plot([int(df["X"][x]), int(df["X2"][x])], [int(df["Y"][x]), int(df["Y2"][x])], color='green')

# %% [markdown]
# ## Second Half Movement

# %%
#draw the pitch
fig,ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

pitch = Pitch(pitch_type='statsbomb', half=False, pitch_length=120, pitch_width=80,
             pitch_color='#22312b', line_color='#c7d5cc')
pitch.draw(ax=ax)
# plt.gca().invert_yaxis()

#draw the player movements
for x in range(len(df['X'])):
    if (df['Player'][x] == "Akram Afif") and (df['Mins'][x] >45):
         plt.plot([int(120-df["X"][x]), int(120-df["X2"][x])], [int(80-df["Y"][x]), int(80-df["Y2"][x])], color='green')
